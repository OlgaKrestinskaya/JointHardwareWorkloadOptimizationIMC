# %%
# This is the code for sequential optimization (step by step) - SRAM

# %%
#FOr SRAM step by step search: device-circuit-arch-system:
#starting form max
# searching for device value:

# %%
from jointSearchSRAMcircuit import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_NEW_StepByStep/SRAM/joint_ELA_constr8_seed1_circuit/'
obj_type='ela'
num_generations=7
population_size=15
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
#hardware_params=[0.7, 4e-09, 128, 128, 8, 32, 32, 16384]
Vinp=0.85 #0.7
#BitsIn=8
base_latIN=10e-09 #4e-09
#XbarXin=512 #256
#XbarYin=512 #256
TrouterIN=32 #8
TchipIN=64 #16
CtileIN=128 #32
GlbIN=131072 #16384


run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,Vinp,base_latIN, TrouterIN, TchipIN, CtileIN, GlbIN)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell(???), base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       12 |  7.400131E+01 |  4.760551E+02 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       25 |  6.789768E+01 |  1.798771E+02 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      3 |       34 |  6.789768E+01 |  1.798771E+02 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      4 |       41 |  6.789768E+01 |  1.798771E+02 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      5 |       50 |  6.789768E+01 |  1.798771E+02 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      6 |       57 |  6.789768E+01 |  1.798771E+02 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      7 |       64 |  6.789768E+01 |  1.798771E+02 |             - |             -
# time in s: 913.8537065982819
# DONE ELA

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStep/SRAM/joint_ELA_constr8_seed1_circuit/'
obj_type='ela'
constr_type='n'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
#     resnet18
# E = 4.1792800696146335 mJ,   L = 0.005820000000000003 ms,   A = 7589.767699800321 mm2
#     vgg16
# E = 26.25579777343357 mJ,   L = 0.012660000000000003 ms,   A = 7589.767699800321 mm2
#     alexnet
# E = 6.304468295938212 mJ,   L = 0.0012499999999999998 ms,   A = 7589.767699800321 mm2
#     mobilenet_v3
# E = 1.3575725287846707 mJ,   L = 0.013690000000000004 ms,   A = 7589.767699800321 mm2
# (['0.85V', '1b', '1e-08s', '32', '32', '32', '64', '128', '32MB'],
#  2728.0803064054135)

# %%
from jointSearchSRAMarchitecture import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_NEW_StepByStep/SRAM/joint_ELA_constr8_seed1_architecture/'
obj_type='ela'
num_generations=10
population_size=20
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
#hardware_params=[0.7, 4e-09, 128, 128, 8, 32, 32, 16384]
Vinp=0.85 #0.7
#BitsIn=8
base_latIN=10e-09 #4e-09
XbarXin=32 #256
XbarYin=32 #256
#TrouterIN=32 #8
#TchipIN=64 #16
#CtileIN=128 #32
#GlbIN=131072 #16384


run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,Vinp,base_latIN, XbarXin, XbarYin)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell(???), base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       20 |  0.000000E+00 |  0.000000E+00 |  0.0002137531 |  0.000000E+00
#      2 |       40 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      3 |       60 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      4 |       80 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      5 |      100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      120 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      140 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      160 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      180 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      200 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# time in s: 3656.7098412513733
# DONE ELA

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStep/SRAM/joint_ELA_constr8_seed1_architecture/'
obj_type='ela'
constr_type='c'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
#     resnet18
# E = 2.2184058058206566 mJ,   L = 0.3910299999999999 ms,   A = 15.433399743359999 mm2
#     vgg16
# E = 21.823124298431907 mJ,   L = 3.14115 ms,   A = 15.433399743359999 mm2
#     alexnet
# E = 5.403823076689058 mJ,   L = 0.14885 ms,   A = 15.433399743359999 mm2
#     mobilenet_v3
# E = 0.7128796430511308 mJ,   L = 0.08441000000000003 ms,   A = 15.433399743359999 mm2
# (['0.85V', '1b', '1e-08s', '32', '32', '1', '16', '32', '0MB'],
#  1057.9550287238283)

# %%
from jointSearchSRAMsystem import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_NEW_StepByStep/SRAM/joint_ELA_constr8_seed1_system/'
obj_type='ela'
num_generations=7
population_size=10
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
#hardware_params=[0.7, 4e-09, 128, 128, 8, 32, 32, 16384]
#Vinp=0.85 #0.7
#base_latIN=10e-09 #4e-09
#BitsIn=8
XbarXin=32 #256
XbarYin=32 #256
TrouterIN=1 #8
TchipIN=16 #16
CtileIN=32 #32
GlbIN=2048 #16384

run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,XbarXin, XbarYin, TrouterIN, TchipIN, CtileIN, GlbIN)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell(???), base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       10 |  0.000000E+00 |  0.000000E+00 |  0.0000110812 |  1.055091E-06
#      2 |       20 |  0.000000E+00 |  0.000000E+00 |  3.162354E-06 |  1.055091E-06
#      3 |       30 |  0.000000E+00 |  0.000000E+00 |  1.391063E-06 |  5.412020E-09
#      4 |       40 |  0.000000E+00 |  0.000000E+00 |  3.195866E-07 |  1.813131E-09
#      5 |       50 |  0.000000E+00 |  0.000000E+00 |  3.060039E-09 |  9.065657E-10
#      6 |       60 |  0.000000E+00 |  0.000000E+00 |  2.025928E-09 |  9.020033E-10
#      7 |       70 |  0.000000E+00 |  0.000000E+00 |  1.290311E-09 |  9.020033E-10
# time in s: 728.6937265396118
# DONE ELA

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStep/SRAM/joint_ELA_constr8_seed1_system/'
obj_type='ela'
constr_type='c'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
#     resnet18
# E = 2.2008566482587075 mJ,   L = 0.03910299999999999 ms,   A = 15.456442815359997 mm2
#     vgg16
# E = 21.57596028038698 mJ,   L = 0.3141150000000001 ms,   A = 15.456442815359997 mm2
#     alexnet
# E = 5.233785175631913 mJ,   L = 0.014884999999999999 ms,   A = 15.456442815359997 mm2
#     mobilenet_v3
# E = 0.6976306180123851 mJ,   L = 0.008440999999999999 ms,   A = 15.456442815359997 mm2
# (['0.8V', '1b', '1e-09s', '32', '32', '1', '16', '32', '0MB'],
#  104.75345629929787)

# %%
# testign the samne but the middle values (not startign from max)

# %%
from jointSearchSRAMcircuit import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_NEW_StepByStepMiddle/SRAM/joint_ELA_constr8_seed1_circuit/'
obj_type='ela'
num_generations=7
population_size=15
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
#hardware_params=[0.7, 4e-09, 128, 128, 8, 32, 32, 16384]
Vinp=0.7
#BitsIn=8
base_latIN=4e-09
#XbarXin=512 #256
#XbarYin=512 #256
TrouterIN=8
TchipIN=32
CtileIN=32
GlbIN=16384


run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,Vinp, base_latIN, TrouterIN, TchipIN, CtileIN, GlbIN)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell(???), base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       12 |  0.000000E+00 |  0.1072330112 |  6.724773E-07 |  0.000000E+00
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      2 |       25 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      3 |       34 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      4 |       44 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      5 |       54 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      6 |       64 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# WARNING: Mating could not produce the required number of (unique) offsprings!
#      7 |       74 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# time in s: 634.6998903751373
# DONE ELA

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStepMiddle/SRAM/joint_ELA_constr8_seed1_circuit/'
obj_type='ela'
constr_type='c'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
#     resnet18
# E = 2.927490756635524 mJ,   L = 0.0027759999999999994 ms,   A = 296.97092804607996 mm2
#     vgg16
# E = 22.950336542011925 mJ,   L = 0.013896000000000002 ms,   A = 296.97092804607996 mm2
#     alexnet
# E = 5.586285491152493 mJ,   L = 0.00078 ms,   A = 296.97092804607996 mm2
#     mobilenet_v3
# E = 0.9588421211180238 mJ,   L = 0.0055320000000000065 ms,   A = 296.97092804607996 mm2
# (['0.7V', '1b', '4e-09s', '256', '32', '8', '32', '32', '4MB'],
#  94.7093377807635)

# %%
from jointSearchSRAMarchitecture import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_NEW_StepByStepMiddle/SRAM/joint_ELA_constr8_seed1_architecture/'
obj_type='ela'
num_generations=10
population_size=20
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
#hardware_params=[0.7, 4e-09, 128, 128, 8, 32, 32, 16384]
Vinp=0.7
BitsIn=8
base_latIN=4e-09
XbarXin=256 #256
XbarYin=32 #256
#TrouterIN=32 #8
#TchipIN=64 #16
#CtileIN=128 #32
#GlbIN=131072 #16384


run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,Vinp, base_latIN, XbarXin, XbarYin)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell(???), base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       20 |  0.000000E+00 |  0.000000E+00 |  4.706860E-06 |  0.000000E+00
#      2 |       40 |  0.000000E+00 |  0.000000E+00 |  1.393199E-07 |  0.000000E+00
#      3 |       60 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      4 |       80 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      5 |      100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      120 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      140 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      160 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      180 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      200 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# time in s: 3422.631339073181
# DONE ELA

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStepMiddle/SRAM/joint_ELA_constr8_seed1_architecture/'
obj_type='ela'
constr_type='c'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
#     resnet18
# E = 2.4604618140942334 mJ,   L = 0.006443999999999999 ms,   A = 76.31288201152002 mm2
#     vgg16
# E = 21.950251102772732 mJ,   L = 0.051980000000000005 ms,   A = 76.31288201152002 mm2
#     alexnet
# E = 5.1886233688074865 mJ,   L = 0.0021800000000000005 ms,   A = 76.31288201152002 mm2
#     mobilenet_v3
# E = 0.9001979734052046 mJ,   L = 0.0075760000000000055 ms,   A = 76.31288201152002 mm2
# (['0.7V', '1b', '4e-09s', '256', '32', '4', '16', '32', '2MB'],
#  87.07101823306432)

# %%
from jointSearchSRAMsystem import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_NEW_StepByStepMiddle/SRAM/joint_ELA_constr8_seed1_system/'
obj_type='ela'
num_generations=7
population_size=15
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
#hardware_params=[0.7, 4e-09, 128, 128, 8, 32, 32, 16384]
#Vinp=0.85 #0.7
#base_latIN=10e-09 #4e-09
#BitsIn=8
XbarXin=256 #256
XbarYin=32 #256
TrouterIN=4 #8
TchipIN=16 #16
CtileIN=32 #32
GlbIN=8192 #16384

run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,XbarXin, XbarYin, TrouterIN, TchipIN, CtileIN, GlbIN)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell(???), base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       12 |  0.000000E+00 |  0.000000E+00 |  3.047761E-06 |  4.134552E-07
#      2 |       27 |  0.000000E+00 |  0.000000E+00 |  9.112683E-07 |  4.051456E-07
#      3 |       42 |  0.000000E+00 |  0.000000E+00 |  1.808486E-07 |  8.618309E-09
#      4 |       57 |  0.000000E+00 |  0.000000E+00 |  8.748038E-09 |  2.707264E-09
#      5 |       72 |  0.000000E+00 |  0.000000E+00 |  4.780013E-09 |  1.353632E-09
#      6 |       87 |  0.000000E+00 |  0.000000E+00 |  3.432318E-09 |  1.300489E-09
#      7 |      102 |  0.000000E+00 |  0.000000E+00 |  2.415074E-09 |  1.300489E-09
# time in s: 1115.4039890766144
# DONE ELA

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStepMiddle/SRAM/joint_ELA_constr8_seed1_system/'
obj_type='ela'
constr_type='c'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
#     resnet18
# E = 2.3918376523713745 mJ,   L = 0.0016109999999999998 ms,   A = 73.85495433151999 mm2
#     vgg16
# E = 21.092822421711954 mJ,   L = 0.012995000000000001 ms,   A = 73.85495433151999 mm2
#     alexnet
# E = 5.397924780343992 mJ,   L = 0.0005450000000000001 ms,   A = 73.85495433151999 mm2
#     mobilenet_v3
# E = 0.9476796179922944 mJ,   L = 0.0018940000000000014 ms,   A = 73.85495433151999 mm2
# (['0.8V', '1b', '1e-09s', '256', '32', '4', '16', '32', '2MB'],
#  20.24373362963578)

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStepMiddle/SRAM/joint_ELA_constr8_seed1_system/'
obj_type='ela'
constr_type='c'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
# Number of entries:  44
# Index of the best design:  43
# Number of entries nonconstrains:  44
# Index of the best design nonconstr:  43
#     resnet18
# E = 2.3918376523713745 mJ,   L = 0.0016109999999999998 ms,   A = 73.85495433151999 mm2
# EDAP (mJ*ms*mm2):  0.2845816366013038
# {'e': 2.3918376523713745, 'a': 73.85495433151999, 'l': 0.0016109999999999998, 'a_tpm': 28.048263746757975, 'a_tpw': 1.5588828384700129, 'u': 65.62, 'au': 48.463621032343426, 'm_tpm': 37.2691585136527, 'm_tpw': 2.449182404133123, 'tp': 2071.503238095238}
#     vgg16
# E = 21.092822421711954 mJ,   L = 0.012995000000000001 ms,   A = 73.85495433151999 mm2
# EDAP (mJ*ms*mm2):  20.243733629635773
# {'e': 21.092822421711954, 'a': 73.85495433151999, 'l': 0.012995000000000001, 'a_tpm': 35.650071464178716, 'a_tpw': 2.077923887026443, 'u': 100.0, 'au': 73.85495433151999, 'm_tpm': 56.791098687470786, 'm_tpw': 3.0196037506860547, 'tp': 2632.934399902343}
#     alexnet
# E = 5.397924780343992 mJ,   L = 0.0005450000000000001 ms,   A = 73.85495433151999 mm2
# EDAP (mJ*ms*mm2):  0.2172716010348207
# {'e': 5.397924780343992, 'a': 73.85495433151999, 'l': 0.0005450000000000001, 'a_tpm': 42.907607978601476, 'a_tpw': 1.1269561697303594, 'u': 100.0, 'au': 73.85495433151999, 'm_tpm': 56.79109868747078, 'm_tpw': 2.2172933269759096, 'tp': 3168.939427734375}
#     mobilenet_v3
# E = 0.9476796179922944 mJ,   L = 0.0018940000000000014 ms,   A = 73.85495433151999 mm2
# EDAP (mJ*ms*mm2):  0.1325626413152468
# {'e': 0.9476796179922944, 'a': 73.85495433151999, 'l': 0.0018940000000000014, 'a_tpm': 7.1438877022610905, 'a_tpw': 0.5693825551599779, 'u': 61.04, 'au': 45.081064123959806, 'm_tpm': 34.66253581998949, 'm_tpw': 1.5425090822934768, 'tp': 527.6114999999999}
# (['0.8V', '1b', '1e-09s', '256', '32', '4', '16', '32', '2MB'],
#  20.24373362963578)
