# %%
# to install inside the docker or here (depending on the docker configuration):

# %%
pip install --user "pymoo==0.6.1.5"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 2.2 MB/s eta 0:00:0000:0100:010m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 KB 2.7 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 KB 117.3 kB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 KB 661.6 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 KB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 KB 257.3 kB/s eta 0:00:0000:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# checking if everything works with a quick test (small population):

# %%
from jointSearchUPDATED_hammingDist_4phaseAggregation import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_test/RRAM_hammig4Phase_MAX/joint_ELA_constr8_seed1_pop70/'
obj_type='ela'
# 30-40% of total time
num_generations1=1 #10
population_size1=2 #40
# 20-30% of total time
num_generations2=1 #10
population_size2=2 #40
# 20-30% of total time
num_generations3=1 #10
population_size3=2 #40
# Phase 4: should be shorter like 10-20% of total time
num_generations4=1 #10
population_size4=2 #40
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
# on-chip area constraint
areaConstrcm2=8
# this sets the number of CPUs used, -1 means all, for 64: n_jobs=64
n_jobs=-1
samplesToEval=4 #for hamming distance
samplesToEvalTest=3  #500 #for accessment thorught scoring
#Early exploration
prob_cross1, prob_mute1, eta_cross1, eta_mute1=1.0, 1.0, 3.0, 3.0
#Transition to balance:
prob_cross2, prob_mute2, eta_cross2, eta_mute2=0.9, 0.5, 7.0, 7.0
# Convergence (exploitation phase):
prob_cross3, prob_mute3, eta_cross3, eta_mute3=1.0, 0.2, 15.0, 15.0
#Final fine-tuning:
prob_cross4, prob_mute4, eta_cross4, eta_mute4=1.0, 0.05, 25.0, 25.0
#run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval)
run_several_iterationsJoint(dnn_names, num_generations1, population_size1, num_iterations_to_run, 
                            seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval,samplesToEvalTest,
                            prob_cross1, prob_mute1, eta_cross1, eta_mute1, 
                            num_generations2, population_size2,prob_cross2, prob_mute2, eta_cross2, eta_mute2, 
                            num_generations3, population_size3,prob_cross3, prob_mute3, eta_cross3, eta_mute3, 
                            num_generations4, population_size4,prob_cross4, prob_mute4, eta_cross4, eta_mute4)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell, base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 25.460124731063843
# Designs with Hamming distance selected in time in s: 25.460124731063843
# Sampling - evaluation finished in time in s: 119.62754917144775
# [np.float64(1.9742263200126263e-07), np.float64(1.238074316822694e-07), np.float64(7.361520031899323e-08)]
# ...
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# ...
#      1 |        2 |  2.730081E+01 |  2.800359E+01 |             - |             -
# time in s: 126.40094685554504
# Sampling finished in time in s: 0.000576019287109375
# [np.float64(1.9742263200126263e-07), np.float64(1.238074316822694e-07), np.float64(7.361520031899323e-08)]
# ...
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# ...
