# %%
# This is the code for sequential optimization (step by step) - RRAM

# %%
#FOr RRAM step by step search: device-circuit-arch-system:
#starting form max
# searching for device value:

# %%
from jointSearchUPDATEDdevice import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_NEW_StepByStep/RRAM/joint_ELA_constr8_seed1_device/'
obj_type='ela'
num_generations=5
population_size=10
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
#hardware_params=[0.7, 4e-09, 128, 128, 8, 32, 32, 16384]
Vinp=0.85 #0.7
base_latIN=10e-09 #4e-09
XbarXin=512 #256
XbarYin=512 #256
TrouterIN=32 #8
TchipIN=64 #16
CtileIN=128 #32
GlbIN=131072 #16384

run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,Vinp, base_latIN, XbarXin, XbarYin, TrouterIN, TchipIN, CtileIN, GlbIN)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell, base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 25.20155096054077
# [np.float64(3.736491828211703e-05), np.float64(2.8684049579650263e-05), np.float64(1.4410435224896964e-05)]
# ...
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# ...
#      1 |        6 |  1.117321E+03 |  1.117321E+03 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
# [np.float64(2.578907291920404e-05), np.float64(7.503436489321149e-06), np.float64(1.828563642988289e-05)]
#      2 |        8 |  1.117321E+03 |  1.117321E+03 |             - |             -
#      3 |        8 |  1.117321E+03 |  1.117321E+03 |             - |             -
# time in s: 367.3944613933563
# DONE ELA

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStep/RRAM/joint_ELA_constr8_seed1_device/'
obj_type='ela'
constr_type='n'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
# (['0.85V', '8b', '1e-08s', '512', '512', '32', '64', '128', '32MB'],
#  1441.0435224896962)

# %%
from jointSearchUPDATEDcircuit import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_NEW_StepByStep/RRAM/joint_ELA_constr8_seed1_circuit/'
obj_type='ela'
num_generations=7
population_size=25
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
#hardware_params=[0.7, 4e-09, 128, 128, 8, 32, 32, 16384]
Vinp=0.85 #0.7
BitsIn=8
base_latIN=10e-09 #4e-09
#XbarXin=512 #256
#XbarYin=512 #256
TrouterIN=32 #8
TchipIN=64 #16
CtileIN=128 #32
GlbIN=131072 #16384


run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,Vinp, BitsIn, base_latIN, TrouterIN, TchipIN, CtileIN, GlbIN)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell, base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 59.59634256362915
# [np.float64(5.092628906673127e-06), np.float64(4.620563775136999e-06), np.float64(8.363003177312833e-07)]
# ...
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# ...
#      1 |       17 |  6.102435E+01 |  4.052211E+02 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
# [np.float64(5.704514201132557e-06), np.float64(4.942086446939171e-06), np.float64(8.672349637679978e-07)]
#      2 |       25 |  6.102435E+01 |  4.213570E+02 |             - |             -
#      3 |       25 |  6.102435E+01 |  4.213570E+02 |             - |             -
# time in s: 1094.2743599414825
# DONE ELA

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStep/RRAM/joint_ELA_constr8_seed1_circuit/'
obj_type='ela'
constr_type='n'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
#     resnet18
# E = 2.298827342505575 mJ,   L = 0.0002100000000000001 ms,   A = 7011.510390202623 mm2
#     vgg16
# E = 18.35005301041223 mJ,   L = 0.0005300000000000001 ms,   A = 7011.510390202623 mm2
#     alexnet
# E = 0.8397976426975726 mJ,   L = 7.999999999999999e-05 ms,   A = 7011.510390202623 mm2
#     mobilenet_v3
# E = 0.9776110348869642 mJ,   L = 0.0006500000000000004 ms,   A = 7011.510390202623 mm2
# (['0.85V', '8b', '1e-08s', '64', '32', '32', '64', '128', '32MB'],
#  83.63003177312832)

# %%
from jointSearchUPDATEDarchitecture import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_NEW_StepByStep/RRAM/joint_ELA_constr8_seed1_architecture_largePop/'
obj_type='ela'
num_generations=10
population_size=70
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
#hardware_params=[0.7, 4e-09, 128, 128, 8, 32, 32, 16384]
Vinp=0.85 #0.7
BitsIn=8
base_latIN=10e-09 #4e-09
XbarXin=64 #256
XbarYin=32 #256
#TrouterIN=32 #8
#TchipIN=64 #16
#CtileIN=128 #32
#GlbIN=131072 #16384


run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,Vinp,BitsIn, base_latIN, XbarXin, XbarYin)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell, base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 2036.154098033905
# [np.float64(6.782170302781772e-07), np.float64(7.856664345155019e-08), np.float64(5.646098854273025e-07)]
# ...
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# ...
#      1 |       28 |  0.000000E+00 |  2.036598E+01 |  0.000000E+00 |  0.000000E+00
# [1e+25, 1e+25, 1e+25]
#      2 |       98 |  0.000000E+00 |  6.000000E+24 |  0.000000E+00 |  0.000000E+00
# [1e+25, 1e+25, 1e+25]
#      3 |      168 |  0.000000E+00 |  6.000000E+24 |  0.000000E+00 |  0.000000E+00
# [1e+25, 1e+25, 1e+25]
#      4 |      238 |  0.000000E+00 |  6.000000E+24 |  0.000000E+00 |  0.000000E+00
# [1e+25, 1e+25, 1e+25]
#      5 |      308 |  0.000000E+00 |  6.000000E+24 |  0.000000E+00 |  0.000000E+00
# [1e+25, 1e+25, 1e+25]
# ...

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStep/RRAM/joint_ELA_constr8_seed1_architecture_largePop/'
obj_type='ela'
constr_type='n'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
#     resnet18
# E = 2.0516798818418693 mJ,   L = 0.0002100000000000001 ms,   A = 3481.3771451013117 mm2
#     vgg16
# E = 16.893754189995736 mJ,   L = 0.0009600000000000001 ms,   A = 3481.3771451013117 mm2
#     alexnet
# E = 0.7875948042457582 mJ,   L = 8.999999999999999e-05 ms,   A = 3481.3771451013117 mm2
#     mobilenet_v3
# E = 0.49600841292267633 mJ,   L = 0.0007000000000000005 ms,   A = 3481.3771451013117 mm2
# (['0.85V', '8b', '1e-08s', '64', '32', '16', '64', '128', '4MB'],
#  56.460988542730256)

# %%
from jointSearchUPDATEDsystem import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_NEW_StepByStep/RRAM/joint_ELA_constr8_seed1_system/'
obj_type='ela'
num_generations=7
population_size=15
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
#hardware_params=[0.7, 4e-09, 128, 128, 8, 32, 32, 16384]
#Vinp=0.85 #0.7
#base_latIN=10e-09 #4e-09
BitsIn=8
XbarXin=64 #256
XbarYin=32 #256
TrouterIN=16 #8
TchipIN=64 #16
CtileIN=128 #32
GlbIN=131072 #16384

run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,BitsIn,XbarXin, XbarYin, TrouterIN, TchipIN, CtileIN, GlbIN)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell, base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 35.041179180145264
# [np.float64(3.7682064233954926e-07), np.float64(1.6999150262952264e-07), np.float64(1.2163129187884958e-07)]
# ...
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# ...
#      1 |       12 |  2.740870E+01 |  2.740870E+01 |             - |             -
# [np.float64(3.5500595770645486e-07), np.float64(1.8776385003126573e-07), np.float64(6.081564593942479e-08)]
#      2 |       27 |  2.740870E+01 |  2.740870E+01 |             - |             -
# [np.float64(1.312206683715966e-07), np.float64(1.294706712583934e-07), np.float64(1.857431836775429e-08)]
#      3 |       42 |  2.740870E+01 |  2.740870E+01 |             - |             -
# ...

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStepNEW/RRAM/joint_ELA_constr8_seed1_system/'
obj_type='ela'
constr_type='n'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
#     resnet18
# E = 2.2116489535841892 mJ,   L = 2.1e-05 ms,   A = 3540.869645101312 mm2
#     vgg16
# E = 17.629435163100673 mJ,   L = 9.6e-05 ms,   A = 3540.869645101312 mm2
#     alexnet
# E = 0.8057683282973163 mJ,   L = 9.000000000000002e-06 ms,   A = 3540.869645101312 mm2
#     mobilenet_v3
# E = 0.9367310507976295 mJ,   L = 7.000000000000001e-05 ms,   A = 3540.869645101312 mm2
# (['0.5V', '8b', '1e-09s', '64', '32', '16', '64', '128', '32MB'],
#  5.9926590556132675)

# %%
# testign the samne but the middle values (not startign from max)

# %%
from jointSearchUPDATEDdevice import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_NEW_StepByStepMiddleNEW/RRAM/joint_ELA_constr8_seed1_device/'
obj_type='ela'
num_generations=5
population_size=10
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
#hardware_params=[0.7, 4e-09, 128, 128, 8, 32, 32, 16384]
Vinp=0.7
base_latIN=4e-09
XbarXin=256
XbarYin=256
TrouterIN=8
TchipIN=16
CtileIN=32
GlbIN=16384

run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,Vinp, base_latIN, XbarXin, XbarYin, TrouterIN, TchipIN, CtileIN, GlbIN)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell, base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 79.99189138412476
# [np.float64(2.846120347365556e-07), np.float64(0.0), np.float64(2.846120347365556e-07)]
# ...
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# ...
#      1 |        1 |  0.7594268251 |  0.7594268251 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
# [1e+25, 1e+25, 1e+25]
#      2 |        6 |  0.7594268251 |  8.333333E+24 |             - |             -
# WARNING: Mating could not produce the required number of (unique) offsprings!
# [1e+25, 1e+25, 1e+25]
#      3 |        8 |  0.7594268251 |  8.750000E+24 |             - |             -
#      4 |        8 |  0.7594268251 |  8.750000E+24 |             - |             -
# time in s: 135.90815138816833
# DONE ELA

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStepMiddleNEW/RRAM/joint_ELA_constr8_seed1_device/'
obj_type='ela'
constr_type='n'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
#     resnet18
# E = 2.061174560828424 mJ,   L = 0.00014000000000000004 ms,   A = 875.9426825093119 mm2
#     vgg16
# E = 16.510205432116077 mJ,   L = 0.000648 ms,   A = 875.9426825093119 mm2
#     alexnet
# E = 0.7663105501084292 mJ,   L = 4.400000000000001e-05 ms,   A = 875.9426825093119 mm2
#     mobilenet_v3
# E = 0.7038778248704829 mJ,   L = 0.001968000000000002 ms,   A = 875.9426825093119 mm2
# (['0.7V', '8b', '4e-09s', '256', '256', '8', '16', '32', '4MB'],
#  28.46120347365556)

# %%
from jointSearchUPDATEDcircuit import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_NEW_StepByStepMiddle/RRAM/joint_ELA_constr8_seed1_circuit/'
obj_type='ela'
num_generations=7
population_size=15
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
#hardware_params=[0.7, 4e-09, 128, 128, 8, 32, 32, 16384]
Vinp=0.7
BitsIn=8
base_latIN=4e-09
#XbarXin=512 #256
#XbarYin=512 #256
TrouterIN=8
TchipIN=16
CtileIN=32
GlbIN=16384


run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,Vinp, BitsIn, base_latIN, TrouterIN, TchipIN, CtileIN, GlbIN)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell, base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 90.44448924064636
# [np.float64(3.831025647514579e-07), np.float64(1.809678424204212e-07), np.float64(1.4766119707286547e-07)]
# ...
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# ...
#      1 |        5 |  0.000000E+00 |  4.1428098560 |  1.476612E-07 |  1.476612E-07
# WARNING: Mating could not produce the required number of (unique) offsprings!
# [np.float64(5.83590629651711e-07), np.float64(0.0), np.float64(5.83590629651711e-07)]
#      2 |       18 |  0.000000E+00 |  6.000000E+24 |  1.476612E-07 |  1.476612E-07
# WARNING: Mating could not produce the required number of (unique) offsprings!
# [1e+25, 1e+25, 1e+25]
#      3 |       26 |  0.000000E+00 |  6.000000E+24 |  1.476612E-07 |  1.476612E-07
# ...

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStepMiddle/RRAM/joint_ELA_constr8_seed1_circuit/'
obj_type='ela'
constr_type='c'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
#     resnet18
# E = 2.0108944772809356 mJ,   L = 0.00011199999999999996 ms,   A = 459.0154356613119 mm2
#     vgg16
# E = 16.34609432371523 mJ,   L = 0.0005480000000000001 ms,   A = 459.0154356613119 mm2
#     alexnet
# E = 0.7628441648147661 mJ,   L = 3.600000000000001e-05 ms,   A = 459.0154356613119 mm2
#     mobilenet_v3
# E = 0.592031863930422 mJ,   L = 0.001968000000000002 ms,   A = 459.0154356613119 mm2
# (['0.7V', '8b', '4e-09s', '512', '128', '8', '16', '32', '4MB'],
#  14.766119707286547)

# %%
from jointSearchUPDATEDarchitecture import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_NEW_StepByStepMiddle/RRAM/joint_ELA_constr8_seed1_architecture/'
obj_type='ela'
num_generations=10
population_size=20
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
#hardware_params=[0.7, 4e-09, 128, 128, 8, 32, 32, 16384]
Vinp=0.7
BitsIn=8
base_latIN=4e-09
XbarXin=512 #256
XbarYin=128 #256
#TrouterIN=32 #8
#TchipIN=64 #16
#CtileIN=128 #32
#GlbIN=131072 #16384


run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,Vinp,BitsIn, base_latIN, XbarXin, XbarYin)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell, base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 73.83138346672058
# [np.float64(2.0216364029657887e-07), np.float64(1.325056822121078e-07), np.float64(1.440006069241374e-07)]
# ...
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# ...
#      1 |       20 |  0.000000E+00 |  7.6548795608 |  9.661865E-08 |  0.000000E+00
# [np.float64(2.461003410489421e-07), np.float64(1.476433795468072e-07), np.float64(1.471965960533116e-07)]
#      2 |       40 |  0.000000E+00 |  0.000000E+00 |  6.877716E-08 |  0.000000E+00
# [np.float64(3.270576468118655e-07), np.float64(3.906003230730038e-07), np.float64(1.4886976045241736e-07)]
#      3 |       60 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# ...

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStepMiddle/RRAM/joint_ELA_constr8_seed1_architecture/'
obj_type='ela'
constr_type='n'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
#     resnet18
# E = 1.9733251026384317 mJ,   L = 0.00011199999999999996 ms,   A = 452.9207856613119 mm2
#     vgg16
# E = 16.145960307164398 mJ,   L = 0.0005480000000000001 ms,   A = 452.9207856613119 mm2
#     alexnet
# E = 0.7557470811968964 mJ,   L = 3.600000000000001e-05 ms,   A = 452.9207856613119 mm2
#     mobilenet_v3
# E = 0.4954473821171225 mJ,   L = 0.001952000000000002 ms,   A = 452.9207856613119 mm2
# (['0.7V', '8b', '4e-09s', '512', '128', '4', '32', '32', '2MB'],
#  14.274665685830819)

# %%
from jointSearchUPDATEDsystem import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_NEW_StepByStepMiddle/RRAM/joint_ELA_constr8_seed1_system/'
obj_type='ela'
num_generations=7
population_size=15
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
#hardware_params=[0.7, 4e-09, 128, 128, 8, 32, 32, 16384]
#Vinp=0.85 #0.7
#base_latIN=10e-09 #4e-09
BitsIn=8
XbarXin=512 #256
XbarYin=128 #256
TrouterIN=4 #8
TchipIN=32 #16
CtileIN=32 #32
GlbIN=8192 #16384

run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,BitsIn,XbarXin, XbarYin, TrouterIN, TchipIN, CtileIN, GlbIN)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell, base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 36.68428587913513
# [np.float64(2.1980689079996785e-07), np.float64(9.934202549666693e-08), np.float64(7.086588383170307e-08)]
# ...
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# ...
#      1 |       12 |  0.000000E+00 |  0.000000E+00 |  2.198069E-07 |  7.086588E-08
# [np.float64(1.657724187585407e-07), np.float64(1.138905581669747e-07), np.float64(3.4782491505369365e-08)]
#      2 |       27 |  0.000000E+00 |  0.000000E+00 |  1.036600E-07 |  3.478249E-08
# [np.float64(7.630101281102677e-08), np.float64(7.69487040371202e-08), np.float64(6.815028235597659e-09)]
#      3 |       42 |  0.000000E+00 |  0.000000E+00 |  3.328772E-08 |  6.815028E-09
# ...

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStepMiddle/RRAM/joint_ELA_constr8_seed1_system/'
obj_type='ela'
constr_type='c'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
#     resnet18
# E = 1.9133889390040841 mJ,   L = 2.799999999999999e-05 ms,   A = 452.9207856613119 mm2
#     vgg16
# E = 15.73687929623244 mJ,   L = 0.00013700000000000002 ms,   A = 452.9207856613119 mm2
#     alexnet
# E = 0.7357152018488033 mJ,   L = 9.000000000000002e-06 ms,   A = 452.9207856613119 mm2
#     mobilenet_v3
# E = 0.43521227237231824 mJ,   L = 0.0004880000000000005 ms,   A = 452.9207856613119 mm2
# (['0.5V', '8b', '1e-09s', '512', '128', '4', '32', '32', '2MB'],
#  3.478249150536936)

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStepMiddle/RRAM/joint_ELA_constr8_seed1_system/'
obj_type='ela'
constr_type='c'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
#     resnet18
# E = 1.9133889390040841 mJ,   L = 2.799999999999999e-05 ms,   A = 452.9207856613119 mm2
#     vgg16
# E = 15.73687929623244 mJ,   L = 0.00013700000000000002 ms,   A = 452.9207856613119 mm2
#     alexnet
# E = 0.7357152018488033 mJ,   L = 9.000000000000002e-06 ms,   A = 452.9207856613119 mm2
#     mobilenet_v3
# E = 0.43521227237231824 mJ,   L = 0.0004880000000000005 ms,   A = 452.9207856613119 mm2
# (['0.5V', '8b', '1e-09s', '512', '128', '4', '32', '32', '2MB'],
#  3.478249150536936)

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC_NEW_StepByStepMiddle/RRAM/joint_ELA_constr8_seed1_system/'
obj_type='ela'
constr_type='c'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
# Number of entries:  46
# Index of the best design:  18
# Number of entries nonconstrains:  46
# Index of the best design nonconstr:  18
#     resnet18
# E = 1.9133889390040841 mJ,   L = 2.799999999999999e-05 ms,   A = 452.9207856613119 mm2
# EDAP (mJ*ms*mm2):  0.024265181402823018
# {'e': 1.9133889390040841, 'a': 452.9207856613119, 'l': 2.799999999999999e-05, 'a_tpm': 314.22542398216683, 'a_tpw': 1.8632432362786806, 'u': 43.07, 'au': 195.07298238432705, 'm_tpm': 510.48884334687267, 'm_tpw': 2.133223456966091, 'tp': 142319.22590476187}
#     vgg16
# E = 15.73687929623244 mJ,   L = 0.00013700000000000002 ms,   A = 452.9207856613119 mm2
# EDAP (mJ*ms*mm2):  0.9764756836548358
# {'e': 15.73687929623244, 'a': 452.9207856613119, 'l': 0.00013700000000000002, 'a_tpm': 482.81204246415837, 'a_tpw': 1.9492335185810248, 'u': 68.91, 'au': 312.10771339921007, 'm_tpm': 816.7821493480966, 'm_tpw': 2.114161758203218, 'tp': 218675.60959960934}
#     alexnet
# ...
