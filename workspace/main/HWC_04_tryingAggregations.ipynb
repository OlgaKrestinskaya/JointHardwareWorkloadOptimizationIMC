# %%
# this is the code for testing differnt aggregation schemes (both SRAM and RRAM) - part 1 (different experiments in different parts)

# %%
from jointSearchUPDATED_hammingDist_4phaseAggregation import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWCaccess/RRAM_hammig4Phase_ALL/joint_ELA_constr8_seed1_pop70/'
obj_type='ela_all'
# 30-40% of total time
num_generations1=10 #10
population_size1=70 #40
# 20-30% of total time
num_generations2=10 #10
population_size2=70 #40
# 20-30% of total time
num_generations3=10 #10
population_size3=70 #40
# Phase 4: should be shorter like 10-20% of total time
num_generations4=10 #10
population_size4=70 #40
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
samplesToEval=1000 #for hamming distance
samplesToEvalTest=500  #500 #for accessment thorught scoring
#Early exploration
prob_cross1, prob_mute1, eta_cross1, eta_mute1=1.0, 1.0, 3.0, 3.0
#Transition to balance:
prob_cross2, prob_mute2, eta_cross2, eta_mute2=0.9, 0.5, 7.0, 7.0
# Convergence (exploitation phase):
prob_cross3, prob_mute3, eta_cross3, eta_mute3=1.0, 0.2, 15.0, 15.0
#Final fine-tuning:
prob_cross4, prob_mute4, eta_cross4, eta_mute4=1.0, 0.05, 25.0, 25.0
#run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval)
run_several_iterationsJoint(dnn_names, num_generations1, population_size1, num_iterations_to_run, 
                            seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval,samplesToEvalTest,
                            prob_cross1, prob_mute1, eta_cross1, eta_mute1, 
                            num_generations2, population_size2,prob_cross2, prob_mute2, eta_cross2, eta_mute2, 
                            num_generations3, population_size3,prob_cross3, prob_mute3, eta_cross3, eta_mute3, 
                            num_generations4, population_size4,prob_cross4, prob_mute4, eta_cross4, eta_mute4)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell, base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 7287.741846561432
# Designs with Hamming distance selected in time in s: 7287.741846561432
# Sampling - evaluation finished in time in s: 23285.281547307968
# [1e+25, 1e+25, 1e+25]
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(5.154793964856996e-34), np.float64(1.0417179235010989e-33), np.float64(1.1775587078654342e-39)]
#      2 |      140 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(1.3967450768503776e-33), np.float64(3.0564459575096796e-33), np.float64(5.859116422420371e-39)]
#      3 |      210 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(1.0042726665188742e-34), np.float64(1.7565622100533745e-34), np.float64(7.009416993179235e-39)]
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(2.62151334432228e-33), np.float64(7.299266582304708e-33), np.float64(2.641864941140706e-39)]
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(1.0206167530934542e-35), np.float64(1.8156679943599805e-35), np.float64(1.0169043961568194e-38)]
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(3.999509849946312e-34), np.float64(8.643875514099201e-34), np.float64(4.287070012999062e-37)]
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(1.0629452317917038e-33), np.float64(2.331309823657377e-33), np.float64(1.4243203315981454e-36)]
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(3.872082903821712e-34), np.float64(1.0221724930221357e-33), np.float64(1.458135353876812e-38)]
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(1.4460506235934572e-35), np.float64(2.3516814454339507e-35), np.float64(3.022442585693698e-38)]
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# time in s: 35070.370359659195
# Sampling finished in time in s: 0.008579730987548828
# [np.float64(5.38515467209816e-36), np.float64(3.1793109392097353e-35), np.float64(2.996816033402454e-40)]
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       68 |  0.000000E+00 |  5.218930E+01 |  2.134752E-35 |  3.340257E-40
# [np.float64(1.496360564368788e-36), np.float64(4.605785631914866e-36), np.float64(6.448141152060337e-40)]
#      2 |      138 |  0.000000E+00 |  5.5527585932 |  1.436605E-35 |  0.000000E+00
# [np.float64(1.6021417573151303e-35), np.float64(7.701496512361017e-35), np.float64(1.379713887497244e-40)]
#      3 |      208 |  0.000000E+00 |  0.3312158259 |  1.719001E-35 |  0.000000E+00
# [np.float64(1.0632254326931634e-35), np.float64(3.809331060058768e-35), np.float64(2.9016381242652842e-40)]
#      4 |      278 |  0.000000E+00 |  0.000000E+00 |  8.327964E-38 |  0.000000E+00
# [np.float64(8.044712290907795e-37), np.float64(3.399877770023619e-36), np.float64(1.3315316074626725e-40)]
#      5 |      348 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(3.915632006190901e-37), np.float64(9.727664736979513e-37), np.float64(1.6191688722647737e-40)]
#      6 |      418 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(9.04981673315397e-36), np.float64(1.5995366897169285e-35), np.float64(1.5252705788887952e-40)]
#      7 |      488 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(1.7761676819562377e-36), np.float64(2.971070303672365e-36), np.float64(3.0915818301628635e-39)]
#      8 |      558 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(6.7598615129455e-37), np.float64(1.581330827007896e-36), np.float64(8.278348734161597e-40)]
#      9 |      628 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(1.423671112563321e-37), np.float64(3.5430337386455357e-37), np.float64(1.4497122530907733e-40)]
#     10 |      698 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# Phase 2 time in s: 48397.92323422432
# Sampling finished in time in s: 0.01071619987487793
# [np.float64(1.7313981627080737e-35), np.float64(6.777418327396138e-35), np.float64(1.3315316074626725e-40)]
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |
#      2 |      140 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      3 |      210 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# time in s: 36529.462272405624
# Sampling finished in time in s: 0.011316537857055664
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  1.327042E+09 |  1.662979E+09 |             - |             -
#      2 |      140 |  0.000000E+00 |  1.388748E+09 |  0.000000E+00 |  0.000000E+00
#      3 |      210 |  0.000000E+00 |  9.054635E+08 |  0.000000E+00 |  0.000000E+00
#      4 |      280 |  0.000000E+00 |  2.096324E+08 |  0.000000E+00 |  0.000000E+00
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# Phase 2 time in s: 57561.998767375946
# Sampling finished in time in s: 0.0171964168548584
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  1.327042E+09 |  1.582810E+09 |             - |             -
#      2 |      140 |  0.000000E+00 |  1.146694E+09 |  0.000000E+00 |  0.000000E+00
#      3 |      210 |  0.000000E+00 |  4.788755E+08 |  0.000000E+00 |  0.000000E+00
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# Phase 3 time in s: 77443.14412546158
# time in s: 77443.14412546158
# Sampling finished in time in s: 0.016359567642211914
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  1.327042E+09 |  1.572306E+09 |             - |             -
#      2 |      140 |  0.000000E+00 |  1.101081E+09 |  0.000000E+00 |  0.000000E+00
#      3 |      210 |  0.000000E+00 |  3.330826E+08 |  0.000000E+00 |  0.000000E+00
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# Total time in s: 95347.59393191338
# DONE ELA

# %%
#checking if works

# %%
from jointSearchUPDATED_hammingDist_4phaseAggregation import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_test/testRRAM_hammig4Phase/joint_ELA_constr8_seed2_pop70/'
obj_type='ela_all'
# 30-40% of total time
num_generations1=1#10 #10
population_size1=2#70 #40
# 20-30% of total time
num_generations2=1#10 #10
population_size2=2#70 #40
# 20-30% of total time
num_generations3=1#10 #10
population_size3=2#70 #40
# Phase 4: should be shorter like 10-20% of total time
num_generations4=1#10 #10
population_size4=2#70 #40
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
samplesToEval=4#1000 #for hamming distance
samplesToEvalTest=3#500  #500 #for accessment thorught scoring
#Early exploration
prob_cross1, prob_mute1, eta_cross1, eta_mute1=1.0, 1.0, 3.0, 3.0
#Transition to balance:
prob_cross2, prob_mute2, eta_cross2, eta_mute2=0.9, 0.5, 7.0, 7.0
# Convergence (exploitation phase):
prob_cross3, prob_mute3, eta_cross3, eta_mute3=1.0, 0.2, 15.0, 15.0
#Final fine-tuning:
prob_cross4, prob_mute4, eta_cross4, eta_mute4=1.0, 0.05, 25.0, 25.0
#run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval)
run_several_iterationsJoint(dnn_names, num_generations1, population_size1, num_iterations_to_run, 
                            seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval,samplesToEvalTest,
                            prob_cross1, prob_mute1, eta_cross1, eta_mute1, 
                            num_generations2, population_size2,prob_cross2, prob_mute2, eta_cross2, eta_mute2, 
                            num_generations3, population_size3,prob_cross3, prob_mute3, eta_cross3, eta_mute3, 
                            num_generations4, population_size4,prob_cross4, prob_mute4, eta_cross4, eta_mute4)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell, base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 28.52748966217041
# Designs with Hamming distance selected in time in s: 28.52748966217041
# Sampling - evaluation finished in time in s: 125.44950008392334
# [np.float64(9.641070687618925e-39), np.float64(9.040999648900873e-39), np.float64(6.000710387180524e-40)]
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  2.730081E+01 |  2.800359E+01 |             - |             -
# time in s: 131.23627305030823
# Sampling finished in time in s: 0.0003857612609863281
# [np.float64(9.641070687618925e-39), np.float64(9.040999648900873e-39), np.float64(6.000710387180524e-40)]
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  2.730081E+01 |  2.800359E+01 |             - |             -
# Phase 2 time in s: 135.713481426239
# Sampling finished in time in s: 0.0006184577941894531
# [np.float64(9.641070687618925e-39), np.float64(9.040999648900873e-39), np.float64(6.000710387180524e-40)]
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  2.730081E+01 |  2.800359E+01 |             - |             -
# Phase 3 time in s: 140.25519680976868
# time in s: 140.25519680976868
# Sampling finished in time in s: 0.0006060600280761719
# [np.float64(9.641070687618925e-39), np.float64(9.040999648900873e-39), np.float64(6.000710387180524e-40)]
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  2.730081E+01 |  2.800359E+01 |             - |             -
# Total time in s: 144.84520506858826
# DONE ELA

# %%
# example of how to display results

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWCaccess/RRAM_hammig4Phase_ALL/joint_ELA_constr8_seed1_pop70/'
obj_type='ela_all'
constr_type='c'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
# Number of entries:  167
# Index of the best design:  91
# Number of entries nonconstrains:  887
# Index of the best design nonconstr:  708
#     resnet18
# E = 1.9137026018938716 mJ,   L = 2.2e-05 ms,   A = 487.10467356531194 mm2
# EDAP (mJ*ms*mm2):  0.020507816586325254
# {'e': 1.9137026018938716, 'a': 487.10467356531194, 'l': 2.2e-05, 'a_tpm': 343.1483764697451, 'a_tpw': 1.864216685601601, 'u': 43.07, 'au': 209.79598290457986, 'm_tpm': 474.6639080829898, 'm_tpw': 2.10967786535435, 'tp': 167149.1779047619}
#     vgg16
# E = 15.864654409571616 mJ,   L = 0.00011499999999999999 ms,   A = 487.10467356531194 mm2
# EDAP (mJ*ms*mm2):  0.8886909403510997
# {'e': 15.864654409571616, 'a': 487.10467356531194, 'l': 0.00011499999999999999, 'a_tpm': 470.0790039180689, 'a_tpw': 1.9364452658807951, 'u': 68.91, 'au': 335.6638305538564, 'm_tpm': 759.4622529263683, 'm_tpw': 2.079456118085958, 'tp': 228977.6797534179}
#     alexnet
# E = 0.7386207563487969 mJ,   L = 9.000000000000002e-06 ms,   A = 487.10467356531194 mm2
# EDAP (mJ*ms*mm2):  0.0032380706016886013
# {'e': 0.7386207563487969, 'a': 487.10467356531194, 'l': 9.000000000000002e-06, 'a_tpm': 309.0783730282019, 'a_tpw': 1.9600683669286803, 'u': 55.7, 'au': 271.31730317587875, 'm_tpm': 613.9147994848873, 'm_tpw': 2.0602845183694307, 'tp': 150553.52000000002}
#     mobilenet_v3
# E = 0.36078180810959093 mJ,   L = 0.00017299999999999984 ms,   A = 487.10467356531194 mm2
# EDAP (mJ*ms*mm2):  0.030402761342081846
# {'e': 0.36078180810959093, 'a': 487.10467356531194, 'l': 0.00017299999999999984, 'a_tpm': 12.468996877719798, 'a_tpw': 1.2809310922286223, 'u': 5.5, 'au': 26.790757046092157, 'm_tpm': 60.569092437673184, 'm_tpw': 2.640849831391245, 'tp': 6073.706653808591}
# (['0.55V', '8b', '1e-09s', '512', '32', '2', '64', '128', '1MB'],
#  1.5523964185717126e-32)

# %%
#FOR SRAM:
# all!
from plotallWithMaxNewAlg import *
folder='results/resHWCaccess/SRAM_hammigDist4Phase_all/joint_ELA_constr8_seed1_forDropGraph40/'
obj_type='ela_all'
constr_type='c'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
# Number of entries:  1035
# Index of the best design:  801
#     resnet18
# E = 1.6179214452523007 mJ,   L = 0.0006029999999999999 ms,   A = 530.37812889216 mm2
# EDAP (mJ*ms*mm2):  0.5174404197429309
# {'e': 1.6179214452523007, 'a': 530.37812889216, 'l': 0.0006029999999999999, 'a_tpm': 15.767918740472139, 'a_tpw': 2.9959745264458313, 'u': 49.22, 'au': 261.05211504072116, 'm_tpm': 31.13829756610863, 'm_tpw': 5.441520630763659, 'tp': 8362.959238095236}
#     vgg16
# E = 13.460738654234214 mJ,   L = 0.0019270000000000003 ms,   A = 530.37812889216 mm2
# EDAP (mJ*ms*mm2):  13.757395221069675
# {'e': 13.460738654234214, 'a': 530.37812889216, 'l': 0.0019270000000000003, 'a_tpm': 35.06775069863732, 'a_tpw': 4.378982304887488, 'u': 100.0, 'au': 530.37812889216, 'm_tpm': 63.26511251526833, 'm_tpw': 7.261362580165444, 'tp': 18599.167999999994}
#     alexnet
# E = 4.333871918623293 mJ,   L = 0.000126 ms,   A = 530.37812889216 mm2
# EDAP (mJ*ms*mm2):  0.2896224507612699
# {'e': 4.333871918623293, 'a': 530.37812889216, 'l': 0.000126, 'a_tpm': 33.38360885465563, 'a_tpw': 2.133521612270573, 'u': 100.0, 'au': 530.37812889216, 'm_tpm': 63.26511251526833, 'm_tpw': 5.288793511961982, 'tp': 17705.935999999998}
#     mobilenet_v3
# E = 0.8044400083451905 mJ,   L = 0.0014880000000000015 ms,   A = 530.37812889216 mm2
# EDAP (mJ*ms*mm2):  0.6348661910109888
# {'e': 0.8044400083451905, 'a': 530.37812889216, 'l': 0.0014880000000000015, 'a_tpm': 1.0761303472150707, 'a_tpw': 0.8548386425990498, 'u': 7.63, 'au': 40.46785123447181, 'm_tpm': 4.826745034429043, 'm_tpw': 2.462475808637656, 'tp': 570.756}
# (['0.55V', '1b', '1e-09s', '256', '128', '16', '8', '32', '8MB'],
#  8.773121982793297e-27)
