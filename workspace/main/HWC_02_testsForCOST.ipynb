# %%
from jointSearchSRAM_hammingDistNew4Phase_cost import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC/SRAM_hammigDist4Phase_cost/joint_ELcost_constr8_seed1/'
obj_type='el_cost'
# 30-40% of total time
num_generations1=10 #10
population_size1=70 #40
# 20-30% of total time
num_generations2=10 #10
population_size2=70 #40
# 20-30% of total time
num_generations3=10 #10
population_size3=70 #40
# Phase 4: should be shorter like 10-20% of total time
num_generations4=10 #10
population_size4=70 #40
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
samplesToEval=1000 #for hamming distance
samplesToEvalTest=500  #500 #for accessment thorught scoring
#Early exploration
prob_cross1, prob_mute1, eta_cross1, eta_mute1=1.0, 1.0, 3.0, 3.0
#Transition to balance:
prob_cross2, prob_mute2, eta_cross2, eta_mute2=0.9, 0.5, 7.0, 7.0
# Convergence (exploitation phase):
prob_cross3, prob_mute3, eta_cross3, eta_mute3=1.0, 0.2, 15.0, 15.0
#Final fine-tuning:
prob_cross4, prob_mute4, eta_cross4, eta_mute4=1.0, 0.05, 25.0, 25.0
#run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval)
run_several_iterationsJoint(dnn_names, num_generations1, population_size1, num_iterations_to_run, 
                            seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval,samplesToEvalTest,
                            prob_cross1, prob_mute1, eta_cross1, eta_mute1, 
                            num_generations2, population_size2,prob_cross2, prob_mute2, eta_cross2, eta_mute2, 
                            num_generations3, population_size3,prob_cross3, prob_mute3, eta_cross3, eta_mute3, 
                            num_generations4, population_size4,prob_cross4, prob_mute4, eta_cross4, eta_mute4)
print('ELA_cost')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell(???), base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 0.0006055831909179688
# Designs with Hamming distance selected in time in s: 0.0006055831909179688
# Sampling - evaluation finished in time in s: 14131.376534938812
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      2 |      140 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      3 |      210 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# time in s: 22564.55806350708
# Sampling finished in time in s: 0.008902549743652344
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  0.000000E+00 |  0.000000E+00 |  2.420571E-07 |  5.303883E-08
#      2 |      140 |  0.000000E+00 |  0.000000E+00 |  2.014902E-07 |  0.000000E+00
#      3 |      210 |  0.000000E+00 |  0.000000E+00 |  1.100904E-07 |  0.000000E+00
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  4.960224E-09 |  0.000000E+00
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# Phase 2 time in s: 36671.66915225983
# Sampling finished in time in s: 0.017787933349609375
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  0.000000E+00 |  0.000000E+00 |  5.923666E-08 |  2.861392E-08
#      2 |      140 |  0.000000E+00 |  0.000000E+00 |  5.441195E-08 |  0.000000E+00
#      3 |      210 |  0.000000E+00 |  0.000000E+00 |  3.893373E-08 |  0.000000E+00
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  1.841128E-08 |  0.000000E+00
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# Phase 3 time in s: 50736.7711148262
# time in s: 50736.7711148262
# Sampling finished in time in s: 0.023659706115722656
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  0.000000E+00 |  0.000000E+00 |  3.234797E-08 |  2.547671E-08
#      2 |      140 |  0.000000E+00 |  0.000000E+00 |  2.465151E-08 |  0.000000E+00
#      3 |      210 |  0.000000E+00 |  0.000000E+00 |  7.971102E-09 |  0.000000E+00
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# Total time in s: 63797.99405384064
# ELA_cost

# %%
#plots:

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWC/SRAM_hammigDist4Phase_cost/joint_ELcost_constr8_seed1/'
obj_type='el_cost'
constr_type='c'
tests=0 #this is for a single case!
#figname='res/new/results_part1/unconstraint/costTry.png'
num_to_plot=10000
scatterCOST(folder, obj_type, constr_type, tests, num_to_plot, num_iterations_to_run=1, num_mapping=None)
# Out:
# ['A_0.75_1_4e-09_256_16_1_2_16_4096_14', 'A_0.55_1_1e-09_32_128_2_2_2_4096_10', 'A_0.55_1_2e-09_128_64_1_2_8_4096_10', 'A_0.55_1_1e-09_256_16_1_4_16_4096_10', 'A_0.7_1_1e-09_256_16_1_8_8_4096_7', 'A_0.65_1_1e-09_256_16_2_8_8_4096_10', 'A_0.75_1_2e-09_256_128_1_16_2_4096_10', 'A_0.5_1_1e-09_256_32_2_8_8_4096_10', 'A_0.6_1_1e-09_128_32_2_16_8_4096_7', 'A_0.5_1_2e-09_256_64_16_4_2_4096_7', 'A_0.6_1_1e-09_128_64_2_4_32_4096_7', 'A_0.5_1_1e-09_128_64_2_4_32_4096_7', 'A_0.5_1_1e-09_256_64_2_8_16_4096_7', 'A_0.5_1_1e-09_256_64_8_4_16_4096_7', 'A_0.5_1_1e-09_256_128_6_8_32_32768_7']
