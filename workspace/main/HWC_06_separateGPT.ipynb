# %%
# how to run single case:

# %%
# testing how single set of design (hardware) parameters for 2 networks:

# %%
from HWC_RunSingleSRAM import *
n_jobs=-1
dnn_names=["resnet18","vgg16"]

#set to -1 to use all the cores
#set to 64 to use 64 cores!
#dnn_names=["alexnet"]
#dnn_names=["mobilenet_v3"]
num_iterations_to_run=1
num_mapping=None
hardware_params=[0.7, 1, 1e-09, 256, 256, 1, 32, 64, 32768]
#Best params separate ['0.6V', '8b', '1e-09s', '256', '128', '8', '64', '16', '2MB']
dictts=runSingle(dnn_names, num_iterations_to_run, num_mapping,n_jobs, hardware_params)
dictts
# Out:
# resnet18
# total required, max_layer:  (93431296, 18874368)
# vgg16
# total required, max_layer:  (1106753024, 822083584)
# {'resnet18': {'e': 0.0018904688710354208,
#   'a': 5.1342682705216,
#   'l': 6.029999999999999e-07,
#   'a_tpm': 16.2885123983707,
#   'a_tpw': 2.5155494876444005,
#   'u': 49.22,
#   'au': 252.70868427507315,
#   'm_tpm': 32.16635970274728,
#   'm_tpw': 4.897136624627033,
#   'tp': 8362.959238095236},
#  'vgg16': {'e': 0.013734842713767934,
#   'a': 5.1342682705216,
#   'l': 1.8990000000000002e-06,
#   'a_tpm': 36.89568016685563,
#   'a_tpw': 4.78271016561842,
#   'u': 100.0,
#   'au': 513.42682705216,
#   'm_tpm': 65.35387368177224,
#   'm_tpw': 8.983065269083768,
#   'tp': 18943.231999999996}}

# %%
# adding more networks:

# %%
from HWC_RunSingleSRAM import *
n_jobs=-1
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3","mobilebert","densenet201","resnet50","vision_transformer","gpt2_medium"]

#set to -1 to use all the cores
#set to 64 to use 64 cores!
#dnn_names=["alexnet"]
#dnn_names=["mobilenet_v3"]
num_iterations_to_run=1
num_mapping=None
hardware_params=[0.7, 1, 1e-09, 256, 256, 1, 32, 64, 32768]
#Best params separate ['0.6V', '8b', '1e-09s', '256', '128', '8', '64', '16', '2MB']
dictts=runSingle(dnn_names, num_iterations_to_run, num_mapping,n_jobs, hardware_params)
dictts
# Out:
# resnet18
# total required, max_layer:  (93431296, 18874368)
# vgg16
# total required, max_layer:  (1106753024, 822083584)
# alexnet
# total required, max_layer:  (488723968, 301989888)
# mobilenet_v3
# total required, max_layer:  (42879160, 10240000)
# mobilebert
# total required, max_layer:  (166568640, 1572864)
# densenet201
# total required, max_layer:  (158270976, 15360000)
# resnet50
# total required, max_layer:  (384302848, 37324800)
# vision_transformer
# total required, max_layer:  (695275872, 18874368)
# gpt2_medium
# total required, max_layer:  (2843353088, 411705344)
# {'resnet18': {'e': 0.0018904688710354208,
#   'a': 5.1342682705216,
#   'l': 6.029999999999999e-07,
#   'a_tpm': 16.2885123983707,
#   'a_tpw': 2.5155494876444005,
#   'u': 49.22,
#   'au': 252.70868427507315,
#   'm_tpm': 32.16635970274728,
#   'm_tpw': 4.897136624627033,
#   'tp': 8362.959238095236},
#  'vgg16': {'e': 0.013734842713767934,
#   'a': 5.1342682705216,
#   'l': 1.8990000000000002e-06,
# ...
