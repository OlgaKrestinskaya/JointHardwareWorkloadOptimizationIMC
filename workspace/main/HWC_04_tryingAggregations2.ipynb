# %%
# this is a short test

# %%
from jointSearchUPDATED_hammingDist_4phaseAggregation import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_test/testRRAM_hammig4Phase/joint_ELA_constr8_seed2_pop70/'
obj_type='ela_mean'
# 30-40% of total time
num_generations1=1#10 #10
population_size1=2#70 #40
# 20-30% of total time
num_generations2=1#10 #10
population_size2=2#70 #40
# 20-30% of total time
num_generations3=1#10 #10
population_size3=2#70 #40
# Phase 4: should be shorter like 10-20% of total time
num_generations4=1#10 #10
population_size4=2#70 #40
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=50
samplesToEval=4#1000 #for hamming distance
samplesToEvalTest=3#500  #500 #for accessment thorught scoring
#Early exploration
prob_cross1, prob_mute1, eta_cross1, eta_mute1=1.0, 1.0, 3.0, 3.0
#Transition to balance:
prob_cross2, prob_mute2, eta_cross2, eta_mute2=0.9, 0.5, 7.0, 7.0
# Convergence (exploitation phase):
prob_cross3, prob_mute3, eta_cross3, eta_mute3=1.0, 0.2, 15.0, 15.0
#Final fine-tuning:
prob_cross4, prob_mute4, eta_cross4, eta_mute4=1.0, 0.05, 25.0, 25.0
#run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval)
run_several_iterationsJoint(dnn_names, num_generations1, population_size1, num_iterations_to_run, 
                            seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval,samplesToEvalTest,
                            prob_cross1, prob_mute1, eta_cross1, eta_mute1, 
                            num_generations2, population_size2,prob_cross2, prob_mute2, eta_cross2, eta_mute2, 
                            num_generations3, population_size3,prob_cross3, prob_mute3, eta_cross3, eta_mute3, 
                            num_generations4, population_size4,prob_cross4, prob_mute4, eta_cross4, eta_mute4)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell, base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 26.416475772857666
# Designs with Hamming distance selected in time in s: 26.416475772857666
# Sampling - evaluation finished in time in s: 152.0237262248993
# [np.float64(1.9770347030234536e-08), np.float64(1.1389224674117208e-08), np.float64(8.381122356117327e-09)]
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  2.730081E+01 |  2.800359E+01 |             - |             -
# time in s: 157.77784395217896
# Sampling finished in time in s: 0.0005931854248046875
# [np.float64(1.9770347030234536e-08), np.float64(1.1389224674117208e-08), np.float64(8.381122356117327e-09)]
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  2.730081E+01 |  2.800359E+01 |             - |             -
# Phase 2 time in s: 162.81139087677002
# Sampling finished in time in s: 0.00034332275390625
# [np.float64(1.9770347030234536e-08), np.float64(1.1389224674117208e-08), np.float64(8.381122356117327e-09)]
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  2.730081E+01 |  2.800359E+01 |             - |             -
# Phase 3 time in s: 167.89909482002258
# time in s: 167.89909482002258
# Sampling finished in time in s: 0.0006089210510253906
# [np.float64(1.9770347030234536e-08), np.float64(1.1389224674117208e-08), np.float64(8.381122356117327e-09)]
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  2.730081E+01 |  2.800359E+01 |             - |             -
# Total time in s: 173.06659364700317
# DONE ELA

# %%
# this is the main code:

# %%
# this is the code for testing differnt aggregation schemes (both SRAM and RRAM) - part 2 (different experiments in different parts)

# %%
from jointSearchUPDATED_hammingDist_4phaseAggregation import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWCaccess/RRAM_hammig4Phase_mean/joint_ELA_constr8_seed1_pop70/'
obj_type='ela_mean'
# 30-40% of total time
num_generations1=10 #10
population_size1=70 #40
# 20-30% of total time
num_generations2=10 #10
population_size2=70 #40
# 20-30% of total time
num_generations3=10 #10
population_size3=70 #40
# Phase 4: should be shorter like 10-20% of total time
num_generations4=10 #10
population_size4=70 #40
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=50
samplesToEval=1000 #for hamming distance
samplesToEvalTest=500  #500 #for accessment thorught scoring
#Early exploration
prob_cross1, prob_mute1, eta_cross1, eta_mute1=1.0, 1.0, 3.0, 3.0
#Transition to balance:
prob_cross2, prob_mute2, eta_cross2, eta_mute2=0.9, 0.5, 7.0, 7.0
# Convergence (exploitation phase):
prob_cross3, prob_mute3, eta_cross3, eta_mute3=1.0, 0.2, 15.0, 15.0
#Final fine-tuning:
prob_cross4, prob_mute4, eta_cross4, eta_mute4=1.0, 0.05, 25.0, 25.0
#run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval)
run_several_iterationsJoint(dnn_names, num_generations1, population_size1, num_iterations_to_run, 
                            seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval,samplesToEvalTest,
                            prob_cross1, prob_mute1, eta_cross1, eta_mute1, 
                            num_generations2, population_size2,prob_cross2, prob_mute2, eta_cross2, eta_mute2, 
                            num_generations3, population_size3,prob_cross3, prob_mute3, eta_cross3, eta_mute3, 
                            num_generations4, population_size4,prob_cross4, prob_mute4, eta_cross4, eta_mute4)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell, base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 6542.533916473389
# Designs with Hamming distance selected in time in s: 6542.533916473389
# Sampling - evaluation finished in time in s: 23159.08216547966
# [1e+25, 1e+25, 1e+25]
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(4.78204847254171e-07), np.float64(5.752122255327618e-07), np.float64(1.0252063119497641e-08)]
#      2 |      140 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(1.819567293336475e-07), np.float64(1.6686443488238362e-07), np.float64(5.86911530790826e-08)]
#      3 |      210 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(2.2324043678661464e-07), np.float64(2.0269648224019417e-07), np.float64(1.3372986926552085e-08)]
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(3.3657675158063847e-07), np.float64(2.4413409133185276e-07), np.float64(5.1579227641958076e-08)]
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(3.5605425905448254e-07), np.float64(5.337933152293808e-07), np.float64(2.3723555931383752e-08)]
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(1.366576500981589e-07), np.float64(7.573094018120279e-08), np.float64(4.044464117464053e-08)]
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(1.5099995576970716e-07), np.float64(1.5882337949900632e-07), np.float64(1.9041216535056086e-08)]
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(2.6616293053484565e-07), np.float64(3.0824806846643357e-07), np.float64(1.4895448696320961e-08)]
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(3.174831029501473e-07), np.float64(4.780546518010082e-07), np.float64(2.420381436973359e-08)]
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# time in s: 35294.049667835236
# Sampling finished in time in s: 0.008922576904296875
# [np.float64(1.9788381431009348e-08), np.float64(1.619866830299326e-08), np.float64(2.458679612958712e-09)]
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       61 |  0.000000E+00 |  7.9260114290 |  2.698843E-08 |  2.458680E-09
# [np.float64(2.9016010300940162e-08), np.float64(4.094544034962373e-08), np.float64(2.4206588869606568e-09)]
#      2 |      131 |  0.000000E+00 |  1.1972116158 |  1.522507E-08 |  0.000000E+00
# [np.float64(1.7567725868073733e-08), np.float64(1.658279451934425e-08), np.float64(1.992646433689213e-09)]
#      3 |      201 |  0.000000E+00 |  0.000000E+00 |  5.091237E-09 |  0.000000E+00
# [np.float64(3.2020871911462854e-08), np.float64(4.113501740487444e-08), np.float64(2.968817058475009e-09)]
#      4 |      271 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(1.872408479915375e-08), np.float64(1.9430461251463943e-08), np.float64(2.468711165664555e-09)]
#      5 |      341 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(3.447683902377545e-08), np.float64(2.6408105956672572e-08), np.float64(2.8062669990673724e-09)]
#      6 |      411 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(3.2348734691358954e-08), np.float64(2.6129230439334618e-08), np.float64(1.879263107795289e-09)]
#      7 |      481 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(3.043028773082506e-08), np.float64(1.6174253676229426e-08), np.float64(9.834025904744212e-09)]
#      8 |      551 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(4.096760286201284e-08), np.float64(3.002113156860827e-08), np.float64(5.2573610075444964e-09)]
#      9 |      621 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(3.806250453826002e-08), np.float64(3.394878773618005e-08), np.float64(1.854413935825499e-09)]
#     10 |      691 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# Phase 2 time in s: 48116.73224902153
# Sampling finished in time in s: 0.01173853874206543
# [np.float64(2.0158545195984703e-08), np.float64(2.0576074388248906e-08), np.float64(1.854413935825499e-09)]
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       64 |  0.000000E+00 |  0.0980286202 |  2.130263E-08 |  1.854414E-09
# [np.float64(1.5136937601957e-08), np.float64(1.9381339801369698e-08), np.float64(1.864741063818806e-09)]
#      2 |      134 |  0.000000E+00 |  0.000000E+00 |  7.877787E-09 |  0.000000E+00
# [np.float64(1.2036577634041978e-08), np.float64(1.682412395346716e-08), np.float64(1.8558063970128648e-09)]
#      3 |      204 |  0.000000E+00 |  0.000000E+00 |  2.094069E-09 |  0.000000E+00
# [np.float64(9.199863968792207e-09), np.float64(9.579459136228324e-09), np.float64(2.3434028356929547e-09)]
#      4 |      274 |  0.000000E+00 |  0.000000E+00 |  2.613244E-10 |  0.000000E+00
# [np.float64(9.168309579721855e-09), np.float64(7.375752742616116e-09), np.float64(1.8760323062628715e-09)]
#      5 |      344 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(9.46502214085187e-09), np.float64(8.420602479662367e-09), np.float64(1.8326777060016898e-09)]
#      6 |      414 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(7.539138687114798e-09), np.float64(7.321462541650133e-09), np.float64(1.869386532943528e-09)]
#      7 |      484 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(8.538069517452307e-09), np.float64(8.222675199976082e-09), np.float64(1.8429658544054759e-09)]
#      8 |      554 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(1.0402640383403372e-08), np.float64(1.0814950048292972e-08), np.float64(1.8429658544054759e-09)]
#      9 |      624 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(1.2345723986568056e-08), np.float64(9.115998583142813e-09), np.float64(2.4039625332903168e-09)]
#     10 |      694 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# Phase 3 time in s: 61085.93761396408
# time in s: 61085.93761396408
# Sampling finished in time in s: 0.0021054744720458984
# [np.float64(4.4761926195290535e-09), np.float64(3.1497330742214466e-09), np.float64(1.8326777060016898e-09)]
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  0.000000E+00 |  0.000000E+00 |  4.476193E-09 |  1.832678E-09
# [np.float64(4.061258977057711e-09), np.float64(2.3358198780598803e-09), np.float64(1.7698798886631328e-09)]
#      2 |      140 |  0.000000E+00 |  0.000000E+00 |  2.403457E-09 |  0.000000E+00
# [np.float64(3.511337104032946e-09), np.float64(1.5292662285072554e-09), np.float64(1.758203304938863e-09)]
#      3 |      210 |  0.000000E+00 |  0.000000E+00 |  1.160315E-09 |  0.000000E+00
# [np.float64(3.9566779294524665e-09), np.float64(1.750693002507952e-09), np.float64(2.220834371051917e-09)]
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  1.293992E-10 |  0.000000E+00
# [np.float64(3.0033533908512495e-09), np.float64(7.218950989979414e-10), np.float64(1.8307060495048345e-09)]
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(4.025000047418576e-09), np.float64(1.8652089109834163e-09), np.float64(2.336983742019192e-09)]
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(3.77739531286761e-09), np.float64(2.320078204849878e-09), np.float64(1.7876623581898002e-09)]
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(3.254006851597049e-09), np.float64(1.3104034891854514e-09), np.float64(1.8980888031219335e-09)]
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(4.730920924903928e-09), np.float64(2.1399132397596034e-09), np.float64(2.2482322282082437e-09)]
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# [np.float64(3.5619134606648115e-09), np.float64(1.0653543744331342e-09), np.float64(1.8186073399757402e-09)]
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# Total time in s: 72883.48763680458
# DONE ELA

# %%
from jointSearchSRAM_hammingDistNew4PhaseAggregation import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWCaccess/SRAM_hammigDist4Phase_mean/joint_ELA_constr8_seed1_forDropGraph40/'
obj_type='ela_mean'
# 30-40% of total time
num_generations1=10 #10
population_size1=70 #40
# 20-30% of total time
num_generations2=10 #10
population_size2=70 #40
# 20-30% of total time
num_generations3=10 #10
population_size3=70 #40
# Phase 4: should be shorter like 10-20% of total time
num_generations4=10 #10
population_size4=70 #40
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=50
samplesToEval=1000 #for hamming distance
samplesToEvalTest=500  #500 #for accessment thorught scoring
#Early exploration
prob_cross1, prob_mute1, eta_cross1, eta_mute1=1.0, 1.0, 3.0, 3.0
#Transition to balance:
prob_cross2, prob_mute2, eta_cross2, eta_mute2=0.9, 0.5, 7.0, 7.0
# Convergence (exploitation phase):
prob_cross3, prob_mute3, eta_cross3, eta_mute3=1.0, 0.2, 15.0, 15.0
#Final fine-tuning:
prob_cross4, prob_mute4, eta_cross4, eta_mute4=1.0, 0.05, 25.0, 25.0
#run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval)
run_several_iterationsJoint(dnn_names, num_generations1, population_size1, num_iterations_to_run, 
                            seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval,samplesToEvalTest,
                            prob_cross1, prob_mute1, eta_cross1, eta_mute1, 
                            num_generations2, population_size2,prob_cross2, prob_mute2, eta_cross2, eta_mute2, 
                            num_generations3, population_size3,prob_cross3, prob_mute3, eta_cross3, eta_mute3, 
                            num_generations4, population_size4,prob_cross4, prob_mute4, eta_cross4, eta_mute4)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell(???), base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 0.0009257793426513672
# Designs with Hamming distance selected in time in s: 0.0009257793426513672
# Sampling - evaluation finished in time in s: 20496.16708779335
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  0.000000E+00 |  5.966686E+08 |  0.000000E+00 |  0.000000E+00
#      2 |      140 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      3 |      210 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# time in s: 33120.740684747696
# Sampling finished in time in s: 0.010506391525268555
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  1.537913E+09 |  1.713658E+09 |             - |             -
#      2 |      140 |  0.000000E+00 |  1.431754E+09 |  0.000000E+00 |  0.000000E+00
#      3 |      210 |  0.000000E+00 |  9.308383E+08 |  0.000000E+00 |  0.000000E+00
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# Phase 2 time in s: 48001.668330430984
# Sampling finished in time in s: 0.01258087158203125
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  1.664679E+09 |  1.714209E+09 |             - |             -
#      2 |      140 |  0.000000E+00 |  1.210867E+09 |  0.000000E+00 |  0.000000E+00
#      3 |      210 |  0.000000E+00 |  2.770614E+08 |  0.000000E+00 |  0.000000E+00
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# Phase 3 time in s: 60567.96651887894
# time in s: 60567.96651887894
# Sampling finished in time in s: 0.015923500061035156
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  1.698233E+09 |  1.717796E+09 |             - |             -
#      2 |      140 |  0.000000E+00 |  1.314739E+09 |  0.000000E+00 |  0.000000E+00
#      3 |      210 |  0.000000E+00 |  4.563951E+08 |  0.000000E+00 |  0.000000E+00
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# Total time in s: 71622.52911639214
# DONE ELA

# %%
#TEST:

# %%
from jointSearchSRAM_hammingDistNew4PhaseAggregation import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_test/SRAM_hammigDist4Phase_mean/joint_ELA_constr8_seed1_forDropGraph40/'
obj_type='ela_mean'
# 30-40% of total time
num_generations1=1#10 #10
population_size1=2#70 #40
# 20-30% of total time
num_generations2=1#10 #10
population_size2=2#70 #40
# 20-30% of total time
num_generations3=1#10 #10
population_size3=2#70 #40
# Phase 4: should be shorter like 10-20% of total time
num_generations4=1#10 #10
population_size4=2#70 #40
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=50
samplesToEval=4#1000 #for hamming distance
samplesToEvalTest=3#500  #500 #for accessment thorught scoring
#Early exploration
prob_cross1, prob_mute1, eta_cross1, eta_mute1=1.0, 1.0, 3.0, 3.0
#Transition to balance:
prob_cross2, prob_mute2, eta_cross2, eta_mute2=0.9, 0.5, 7.0, 7.0
# Convergence (exploitation phase):
prob_cross3, prob_mute3, eta_cross3, eta_mute3=1.0, 0.2, 15.0, 15.0
#Final fine-tuning:
prob_cross4, prob_mute4, eta_cross4, eta_mute4=1.0, 0.05, 25.0, 25.0
#run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval)
run_several_iterationsJoint(dnn_names, num_generations1, population_size1, num_iterations_to_run, 
                            seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval,samplesToEvalTest,
                            prob_cross1, prob_mute1, eta_cross1, eta_mute1, 
                            num_generations2, population_size2,prob_cross2, prob_mute2, eta_cross2, eta_mute2, 
                            num_generations3, population_size3,prob_cross3, prob_mute3, eta_cross3, eta_mute3, 
                            num_generations4, population_size4,prob_cross4, prob_mute4, eta_cross4, eta_mute4)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell(???), base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 0.00010728836059570312
# Designs with Hamming distance selected in time in s: 0.00010728836059570312
# Sampling - evaluation finished in time in s: 134.27988481521606
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  3.301123E+07 |  8.813508E+08 |             - |             -
# time in s: 139.8635036945343
# Sampling finished in time in s: 0.0006830692291259766
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  1.729690E+09 |  1.730346E+09 |             - |             -
# Phase 2 time in s: 144.99138116836548
# Sampling finished in time in s: 0.0006670951843261719
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  1.729690E+09 |  1.730346E+09 |             - |             -
# Phase 3 time in s: 150.05811524391174
# time in s: 150.05811524391174
# Sampling finished in time in s: 0.0007429122924804688
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  1.729690E+09 |  1.730346E+09 |             - |             -
# Total time in s: 155.16908979415894
# DONE ELA

# %%
#quick test:

# %%
from jointSearchSRAM_hammingDistNew4PhaseAggregation import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_test/testSRAM_hammigDist4Phase_all/joint_ELA_constr8_seed1_forDropGraph40/'
obj_type='ela_all'
# 30-40% of total time
num_generations1=1#10 #10
population_size1=2#70 #40
# 20-30% of total time
num_generations2=1#10 #10
population_size2=2#70 #40
# 20-30% of total time
num_generations3=1#10 #10
population_size3=2#70 #40
# Phase 4: should be shorter like 10-20% of total time
num_generations4=1#10 #10
population_size4=2#70 #40
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=50
samplesToEval=4#1000 #for hamming distance
samplesToEvalTest=3#500  #500 #for accessment thorught scoring
#Early exploration
prob_cross1, prob_mute1, eta_cross1, eta_mute1=1.0, 1.0, 3.0, 3.0
#Transition to balance:
prob_cross2, prob_mute2, eta_cross2, eta_mute2=0.9, 0.5, 7.0, 7.0
# Convergence (exploitation phase):
prob_cross3, prob_mute3, eta_cross3, eta_mute3=1.0, 0.2, 15.0, 15.0
#Final fine-tuning:
prob_cross4, prob_mute4, eta_cross4, eta_mute4=1.0, 0.05, 25.0, 25.0
#run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval)
run_several_iterationsJoint(dnn_names, num_generations1, population_size1, num_iterations_to_run, 
                            seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval,samplesToEvalTest,
                            prob_cross1, prob_mute1, eta_cross1, eta_mute1, 
                            num_generations2, population_size2,prob_cross2, prob_mute2, eta_cross2, eta_mute2, 
                            num_generations3, population_size3,prob_cross3, prob_mute3, eta_cross3, eta_mute3, 
                            num_generations4, population_size4,prob_cross4, prob_mute4, eta_cross4, eta_mute4)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell(???), base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 0.00010442733764648438
# Designs with Hamming distance selected in time in s: 0.00010442733764648438
# Sampling - evaluation finished in time in s: 131.21342849731445
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  3.301123E+07 |  8.813508E+08 |             - |             -
# time in s: 137.0169539451599
# Sampling finished in time in s: 0.0007596015930175781
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  1.729690E+09 |  1.730346E+09 |             - |             -
# Phase 2 time in s: 142.07520866394043
# Sampling finished in time in s: 0.0005340576171875
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  1.729690E+09 |  1.730346E+09 |             - |             -
# Phase 3 time in s: 147.13634753227234
# time in s: 147.13634753227234
# Sampling finished in time in s: 0.0006937980651855469
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  1.729690E+09 |  1.730346E+09 |             - |             -
# Total time in s: 152.21253490447998
# DONE ELA

# %%
# display results

# %%
from plotallWithMaxNewAlg import *
folder='results/resHWCaccess/RRAM_hammig4Phase_mean/joint_ELA_constr8_seed1_pop70/'
obj_type='ela_mean'
constr_type='c'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
# Number of entries:  168
# Index of the best design:  145
# Number of entries nonconstrains:  905
# Index of the best design nonconstr:  825
#     resnet18
# E = 1.9253430752074796 mJ,   L = 2.2e-05 ms,   A = 481.598306365312 mm2
# EDAP (mJ*ms*mm2):  0.02039932321222628
# {'e': 1.9253430752074796, 'a': 481.598306365312, 'l': 2.2e-05, 'a_tpm': 347.07177266934247, 'a_tpw': 1.8527471629459886, 'u': 43.07, 'au': 207.4243905515399, 'm_tpm': 480.0909906535614, 'm_tpw': 2.084089163003116, 'tp': 167149.1779047619}
#     vgg16
# E = 15.99582709086411 mJ,   L = 0.00011800000000000001 ms,   A = 481.598306365312 mm2
# EDAP (mJ*ms*mm2):  0.9090204618329587
# {'e': 15.99582709086411, 'a': 481.598306365312, 'l': 0.00011800000000000001, 'a_tpm': 489.1046037465275, 'a_tpw': 1.922572676233738, 'u': 68.91, 'au': 331.8693929163365, 'm_tpm': 768.1455850392094, 'm_tpw': 2.05296046753629, 'tp': 235551.9487998047}
#     alexnet
# E = 0.743789825638957 mJ,   L = 9.000000000000002e-06 ms,   A = 481.598306365312 mm2
# EDAP (mJ*ms*mm2):  0.0032238712828752524
# {'e': 0.743789825638957, 'a': 481.598306365312, 'l': 9.000000000000002e-06, 'a_tpm': 312.61222892631815, 'a_tpw': 1.9482282689073553, 'u': 55.7, 'au': 268.2502566454788, 'm_tpm': 620.9340108708052, 'm_tpw': 2.043966003056857, 'tp': 150553.52000000002}
#     mobilenet_v3
# E = 0.3618397962367633 mJ,   L = 0.00015799999999999986 ms,   A = 481.598306365312 mm2
# EDAP (mJ*ms*mm2):  0.027533306420824754
# {'e': 0.3618397962367633, 'a': 481.598306365312, 'l': 0.00015799999999999986, 'a_tpm': 12.62762427799159, 'a_tpw': 1.28066572582527, 'u': 5.5, 'au': 26.487906850092163, 'm_tpm': 61.261610786522155, 'm_tpw': 2.666149305726189, 'tp': 6081.442465698239}
# (['0.6V', '8b', '1e-09s', '512', '32', '8', '64', '32', '1MB'],
#  0.17582033049388632)

# %%
# SRAM:
#FOR SRAM:
# all!
from plotallWithMaxNewAlg import *
folder='results/resHWCaccess/SRAM_hammigDist4Phase_mean/joint_ELA_constr8_seed1_forDropGraph40/'
obj_type='ela_mean'
constr_type='c'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED(folder, obj_type, constr_type, tests)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
# Number of entries:  1083
# Index of the best design:  875
# Number of entries nonconstrains:  1119
# Index of the best design nonconstr:  911
#     resnet18
# E = 1.4412591791186549 mJ,   L = 0.0030459999999999997 ms,   A = 34.91935272576 mm2
# EDAP (mJ*ms*mm2):  0.15329859346631547
# {'e': 1.4412591791186549, 'a': 34.91935272576, 'l': 0.0030459999999999997, 'a_tpm': 34.51965583134082, 'a_tpw': 3.9286753195378075, 'u': 87.5, 'au': 30.55443363504, 'm_tpm': 52.5498858587466, 'm_tpw': 7.497456862632196, 'tp': 1205.4040379464288}
#     vgg16
# E = 13.087000000283137 mJ,   L = 0.025374000000000008 ms,   A = 34.91935272576 mm2
# EDAP (mJ*ms*mm2):  11.59565332715304
# {'e': 13.087000000283137, 'a': 34.91935272576, 'l': 0.025374000000000008, 'a_tpm': 38.85592007587106, 'a_tpw': 4.893036222871397, 'u': 100.0, 'au': 34.91935272576, 'm_tpm': 60.05701240999611, 'm_tpw': 8.690578689644278, 'tp': 1356.8235786132807}
#     alexnet
# E = 4.242967942721073 mJ,   L = 0.001051 ms,   A = 34.91935272576 mm2
# EDAP (mJ*ms*mm2):  0.15571794059996383
# {'e': 4.242967942721073, 'a': 34.91935272576, 'l': 0.001051, 'a_tpm': 46.468509837168384, 'a_tpw': 2.7186351010994185, 'u': 100.0, 'au': 34.91935272576, 'm_tpm': 60.057012409996105, 'm_tpw': 6.790407815596426, 'tp': 1622.650285644531}
#     mobilenet_v3
# E = 0.6184485765846044 mJ,   L = 0.007335000000000001 ms,   A = 34.91935272576 mm2
# EDAP (mJ*ms*mm2):  0.15840536895566218
# {'e': 0.6184485765846044, 'a': 34.91935272576, 'l': 0.007335000000000001, 'a_tpm': 9.698230573279645, 'a_tpw': 1.2265664806672736, 'u': 71.78, 'au': 25.06511138655053, 'm_tpm': 43.10732824350306, 'm_tpw': 3.3893709327548813, 'tp': 338.65593420410147}
# (['0.55V', '1b', '1e-09s', '256', '128', '1', '32', '8', '1MB'],
#  1.5575262305077657)
