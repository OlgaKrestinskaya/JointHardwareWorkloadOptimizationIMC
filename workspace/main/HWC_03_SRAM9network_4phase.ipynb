# %%
#this is the test for a small population to make sure everything works before runnign the large test

# %%
from jointSearchSRAM_hammingDistNew4Phaselarge import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3","gpt2_medium","mobilebert","densenet201","resnet50","vision_transformer"]
num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_test/SRAM_hammigDist4Phase/joint_ELA_constr8_seed1_forDropGraph40/'
obj_type='ela_mean'
# 30-40% of total time
num_generations1=1#10 #10
population_size1=2#70 #40
# 20-30% of total time
num_generations2=1#10 #10
population_size2=2#70 #40
# 20-30% of total time
num_generations3=1#10 #10
population_size3=2#70 #40
# Phase 4: should be shorter like 10-20% of total time
num_generations4=1#10 #10
population_size4=2#70 #40
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
samplesToEval=3#1000 #for hamming distance
samplesToEvalTest=2#500  #500 #for accessment thorught scoring
#Early exploration
prob_cross1, prob_mute1, eta_cross1, eta_mute1=1.0, 1.0, 3.0, 3.0
#Transition to balance:
prob_cross2, prob_mute2, eta_cross2, eta_mute2=0.9, 0.5, 7.0, 7.0
# Convergence (exploitation phase):
prob_cross3, prob_mute3, eta_cross3, eta_mute3=1.0, 0.2, 15.0, 15.0
#Final fine-tuning:
prob_cross4, prob_mute4, eta_cross4, eta_mute4=1.0, 0.05, 25.0, 25.0
#run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval)
run_several_iterationsJoint(dnn_names, num_generations1, population_size1, num_iterations_to_run, 
                            seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval,samplesToEvalTest,
                            prob_cross1, prob_mute1, eta_cross1, eta_mute1, 
                            num_generations2, population_size2,prob_cross2, prob_mute2, eta_cross2, eta_mute2, 
                            num_generations3, population_size3,prob_cross3, prob_mute3, eta_cross3, eta_mute3, 
                            num_generations4, population_size4,prob_cross4, prob_mute4, eta_cross4, eta_mute4)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell(???), base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 0.00010800361633300781
# Designs with Hamming distance selected in time in s: 0.00010800361633300781
# Sampling - evaluation finished in time in s: 313.1447072029114
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  0.000000E+00 |  2.952031E+09 |  0.000000E+00 |  0.000000E+00
# time in s: 345.3867917060852
# Sampling finished in time in s: 0.001306772232055664
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  5.904061E+09 |  5.932373E+09 |             - |             -
# Phase 2 time in s: 741.6669464111328
# Sampling finished in time in s: 0.0010526180267333984
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  5.904061E+09 |  5.932373E+09 |             - |             -
# Phase 3 time in s: 765.1177458763123
# time in s: 765.1177458763123
# Sampling finished in time in s: 0.0009875297546386719
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |        2 |  5.904061E+09 |  5.932373E+09 |             - |             -
# Total time in s: 788.4649784564972
# DONE ELA

# %%
# main test

# %%
from jointSearchSRAM_hammingDistNew4Phaselarge import *
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3","gpt2_medium","mobilebert","densenet201","resnet50","vision_transformer"]

num_mapping=None

print('Starting random seed')
 #directory = 'res/'+'NeuroSimLikeJointAreaConst_Latency/'+dnn_name
dir_noDNNname='results/resHWC_NEW/SRAM_hammigDist4Phase/joint_ELA_constr8_seed1_forDropGraph40/'
obj_type='ela_mean'
# 30-40% of total time
num_generations1=10 #10
population_size1=70 #40
# 20-30% of total time
num_generations2=10 #10
population_size2=70 #40
# 20-30% of total time
num_generations3=10 #10
population_size3=70 #40
# Phase 4: should be shorter like 10-20% of total time
num_generations4=10 #10
population_size4=70 #40
num_iterations_to_run=1
#seed_alg1=None
seed_alg1=1
areaConstrcm2=8
n_jobs=-1
samplesToEval=1000 #for hamming distance
samplesToEvalTest=500  #500 #for accessment thorught scoring
#Early exploration
prob_cross1, prob_mute1, eta_cross1, eta_mute1=1.0, 1.0, 3.0, 3.0
#Transition to balance:
prob_cross2, prob_mute2, eta_cross2, eta_mute2=0.9, 0.5, 7.0, 7.0
# Convergence (exploitation phase):
prob_cross3, prob_mute3, eta_cross3, eta_mute3=1.0, 0.2, 15.0, 15.0
#Final fine-tuning:
prob_cross4, prob_mute4, eta_cross4, eta_mute4=1.0, 0.05, 25.0, 25.0
#run_several_iterationsJoint(dnn_names, num_generations, population_size, num_iterations_to_run, seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval)
run_several_iterationsJoint(dnn_names, num_generations1, population_size1, num_iterations_to_run, 
                            seed_alg1,areaConstrcm2,dir_noDNNname,obj_type,num_mapping,n_jobs,samplesToEval,samplesToEvalTest,
                            prob_cross1, prob_mute1, eta_cross1, eta_mute1, 
                            num_generations2, population_size2,prob_cross2, prob_mute2, eta_cross2, eta_mute2, 
                            num_generations3, population_size3,prob_cross3, prob_mute3, eta_cross3, eta_mute3, 
                            num_generations4, population_size4,prob_cross4, prob_mute4, eta_cross4, eta_mute4)
print('DONE ELA')
# Out:
# Starting random seed
# Iteration 0
# A: voltage, bits_per_cell(???), base_latency, crossbar_sizeX, crossbar_sizeY, shared_router_groupSize, tiles_in_chip, macros_in_tile, glb_buffer_depth
# Sampling finished in time in s: 0.0003294944763183594
# Designs with Hamming distance selected in time in s: 0.0003294944763183594
# Sampling - evaluation finished in time in s: 128367.62138938904
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      2 |      140 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      3 |      210 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# time in s: 170490.37425923347
# Sampling finished in time in s: 0.021730899810791016
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  4.176232E+09 |  5.750244E+09 |             - |             -
#      2 |      140 |  0.000000E+00 |  4.398107E+09 |  0.000000E+00 |  0.000000E+00
#      3 |      210 |  0.000000E+00 |  2.168616E+09 |  0.000000E+00 |  0.000000E+00
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# Phase 2 time in s: 238516.24716305733
# Sampling finished in time in s: 0.8158512115478516
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  4.176232E+09 |  5.656069E+09 |             - |             -
#      2 |      140 |  0.000000E+00 |  4.099410E+09 |  0.000000E+00 |  0.000000E+00
#      3 |      210 |  0.000000E+00 |  1.895578E+09 |  0.000000E+00 |  0.000000E+00
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# Phase 3 time in s: 301709.041741848
# time in s: 301709.041741848
# Sampling finished in time in s: 0.02745842933654785
# =================================================================================
# n_gen  |  n_eval  |     cv_min    |     cv_avg    |     f_avg     |     f_min
# =================================================================================
#      1 |       70 |  4.903724E+09 |  5.584987E+09 |             - |             -
#      2 |      140 |  0.000000E+00 |  3.840969E+09 |  0.000000E+00 |  0.000000E+00
#      3 |      210 |  0.000000E+00 |  1.208341E+09 |  0.000000E+00 |  0.000000E+00
#      4 |      280 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      5 |      350 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      6 |      420 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      7 |      490 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      8 |      560 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#      9 |      630 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
#     10 |      700 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00
# Total time in s: 358635.97005558014
# DONE ELA

# %%
# parameters of the best:

# %%
from plotallWithMaxNewAlg import *
#tutorials/resHWC_NEW/SRAM/separate_ELA_constr8_seed1/gpt2_medium/Constrtest0.json
dnn_names=["resnet18","vgg16","alexnet","mobilenet_v3","mobilebert","densenet201","resnet50","vision_transformer","gpt2_medium"]
#tutorials/resHWC/SRAM_DRAM/joint_ELA_constr8_seed1
folder='results/resHWC_NEW/SRAM_hammigDist4Phase/joint_ELA_constr8_seed1_forDropGraph40/'
obj_type='ela_mean'
constr_type='c'
tests=0 #this is for a single case!
display_resultsSINGLEforSEED_specific(folder, obj_type, constr_type, tests,dnn_names)
#display_resultsCOST(folder, obj_type, constr_type, tests)
# Out:
#     resnet18
# E = 1.0693760432587407 mJ,   L = 0.003515 ms,   A = 19.72566680576 mm2
# EDAP (mJ*ms*mm2):  0.07414595665063445
# {'e': 1.0693760432587407, 'a': 19.72566680576, 'l': 0.003515, 'a_tpm': 51.40406347507306, 'a_tpw': 5.714917448366651, 'u': 56.25, 'au': 11.09568757824, 'm_tpm': 59.80269319238102, 'm_tpw': 10.794801361837598, 'tp': 1013.9794285714286}
#     vgg16
# E = 10.96059248979424 mJ,   L = 0.027558000000000006 ms,   A = 19.72566680576 mm2
# EDAP (mJ*ms*mm2):  5.958177264539357
# {'e': 10.96059248979424, 'a': 19.72566680576, 'l': 0.027558000000000006, 'a_tpm': 64.9809211836484, 'a_tpw': 8.169924264826816, 'u': 100.0, 'au': 19.72566680576, 'm_tpm': 106.31589900867739, 'm_tpw': 16.80902792719136, 'tp': 1281.7919999999997}
#     alexnet
# E = 4.066610367067582 mJ,   L = 0.001051 ms,   A = 19.72566680576 mm2
# EDAP (mJ*ms*mm2):  0.08430764778723535
# {'e': 4.066610367067582, 'a': 19.72566680576, 'l': 0.001051, 'a_tpm': 82.26085848569177, 'a_tpw': 4.004605013454648, 'u': 100.0, 'au': 19.72566680576, 'm_tpm': 106.31589900867736, 'm_tpw': 12.239542534858217, 'tp': 1622.650285644531}
#     mobilenet_v3
# E = 0.7071491065790457 mJ,   L = 0.049796999999999994 ms,   A = 19.72566680576 mm2
# EDAP (mJ*ms*mm2):  0.6946177384238071
# {'e': 0.7071491065790457, 'a': 19.72566680576, 'l': 0.049796999999999994, 'a_tpm': 13.787878548478181, 'a_tpw': 1.3693094193608784, 'u': 71.78, 'au': 14.159083633174529, 'm_tpm': 76.3107282923612, 'm_tpw': 4.075803422370617, 'tp': 271.9750982055664}
#     mobilebert
# E = 1.9744607099128815 mJ,   L = 0.006442999999999996 ms,   A = 19.72566680576 mm2
# EDAP (mJ*ms*mm2):  0.2509390909684039
# {'e': 1.9744607099128815, 'a': 19.72566680576, 'l': 0.006442999999999996, 'a_tpm': 55.172009393038365, 'a_tpw': 2.539327449250185, 'u': 96.53, 'au': 19.041186167600127, 'm_tpm': 102.62437456151714, 'm_tpw': 3.3178887822445704, 'tp': 1088.3046742913375}
#     densenet201
# E = 2.1464548428805577 mJ,   L = 0.010061000000000054 ms,   A = 19.72566680576 mm2
# EDAP (mJ*ms*mm2):  0.425985285878421
# {'e': 2.1464548428805577, 'a': 19.72566680576, 'l': 0.010061000000000054, 'a_tpm': 46.59520620967923, 'a_tpw': 3.642171941088682, 'u': 91.55, 'au': 18.05884796067328, 'm_tpm': 97.33511261780767, 'm_tpw': 10.64663396020714, 'tp': 919.1215124378101}
#     resnet50
# E = 4.304858307159305 mJ,   L = 0.014785999999999994 ms,   A = 19.72566680576 mm2
# EDAP (mJ*ms*mm2):  1.255570942264298
# {'e': 4.304858307159305, 'a': 19.72566680576, 'l': 0.014785999999999994, 'a_tpm': 59.725627498988295, 'a_tpw': 8.706001072127867, 'u': 100.0, 'au': 19.72566680576, 'm_tpm': 106.31589900867739, 'm_tpw': 25.994875890064552, 'tp': 1178.1278278099792}
#     vision_transformer
# E = 8.917425418242292 mJ,   L = 0.023873000000000037 ms,   A = 19.72566680576 mm2
# EDAP (mJ*ms*mm2):  4.199312326925292
# {'e': 8.917425418242292, 'a': 19.72566680576, 'l': 0.023873000000000037, 'a_tpm': 54.99262533243624, 'a_tpw': 2.8357047079672766, 'u': 75.0, 'au': 14.79425010432, 'm_tpm': 79.73692425650803, 'm_tpw': 4.712627731062023, 'tp': 1084.7662040816333}
#     gpt2_medium
# E = 31.9423607305995 mJ,   L = 0.08660000000000008 ms,   A = 19.72566680576 mm2
# EDAP (mJ*ms*mm2):  54.56530598831982
# {'e': 31.9423607305995, 'a': 19.72566680576, 'l': 0.08660000000000008, 'a_tpm': 84.3060018139929, 'a_tpw': 3.939244029030274, 'u': 100.0, 'au': 19.72566680576, 'm_tpm': 106.31589900867736, 'm_tpw': 5.85346300236761, 'tp': 1662.9921015086218}
# (['0.5V', '1b', '1e-09s', '512', '512', '1', '2', '16', '1MB'],
#  3.600084277699137)
